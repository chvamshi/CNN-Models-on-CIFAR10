# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torchvision.models as models
import torchvision.utils

from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import time

# Use GPU if it is present
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
batch_size = 1000

transform = transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_data = datasets.CIFAR10(root="./data", train=True, download=True, transform=transform)
test_data = datasets.CIFAR10(root="./data", train=False, download=True, transform=transform)

# Split train data into training and valdation test sets
# https://stackoverflow.com/questions/57789645/torch-utils-data-random-split-is-not-splitting-the-data
train_size = int(0.8*len(train_data))
val_size = len(train_data) - train_size
train_data, val_data = torch.utils.data.random_split(train_data, [train_size, val_size])

train_loader = DataLoader(train_data,batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
class Train():
  def __init__(self, name, model, optimizer, loss_fn, train_loader, val_loader, epochs):
    self.name = name
    self.model = model
    self.optimizer = optimizer
    self.loss_fn = loss_fn
    self.train_loader = train_loader
    self.val_loader = val_loader

    self.epochs = epochs
    self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

  def train_val(self):
    self.best_val_loss = float('inf')
    
    self.train_losses = []
    self.train_accuracies = []

    self.val_losses = []
    self.val_accuracies = []

    for epoch in range(self.epochs):
      start_time = time.monotonic()

      self.train_loss, self.train_accuracy = self.train()
      self.val_loss, self.val_accuracy = self.evaluate()

      if self.val_loss < self.best_val_loss:
        best_val_loss = self.val_loss
        torch.save(self.model.state_dict(), '/content/drive/MyDrive/Colab Notebooks/Validation_state/'+self.name+'.pth')

      self.train_losses.append(self.train_loss)
      self.train_accuracies.append(self.train_accuracy)

      self.val_losses.append(self.val_loss)
      self.val_accuracies.append(self.val_accuracy)

      end_time = time.monotonic()

      epoch_mins, epoch_secs = self.epoch_time(start_time, end_time)

      print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
      print(f'\tTrain Loss: {self.train_loss:.3f} | Train Acc: {self.train_accuracy*100:.2f}%')
      print(f'\tVal.  Loss: {self.val_loss:.3f} | Val. Acc: {self.val_accuracy*100:.2f}%')
      print("="*75)

    self.save()

  def save(self):
    df = pd.DataFrame()

    df['Train Loss'] = self.train_losses
    df['Train Accracy'] = self.train_accuracies

    df['Validation Loss'] = self.val_losses
    df['Validation Accuracy'] = self.val_accuracies

    df.to_csv('/content/drive/MyDrive/Colab Notebooks/Saved_CSV/'+self.name+'.csv')
    
  def train(self):
    avg_losses = []
    avg_accuracies = []
    for i, data in enumerate(self.train_loader):
      inputs, labels = data[0].to(self.device), data[1].to(self.device)

      self.optimizer.zero_grad()

      y_pred = self.model(inputs)
      loss = self.loss_fn(y_pred, labels)

      loss.backward()
      self.optimizer.step()

      y_pred = y_pred.argmax(1)
      accuracy = accuracy_score(labels.cpu().detach().numpy(), y_pred.cpu().detach().numpy())
      
      avg_losses.append(loss.item())
      avg_accuracies.append(accuracy)

    avg_loss = sum(avg_losses) / len(avg_losses)
    avg_accuracy = sum(avg_accuracies) / len(avg_accuracies)
    
    return avg_loss, avg_accuracy

  def evaluate(self):
    avg_losses = []
    avg_accuracies = []

    with torch.no_grad():
      for i, data in enumerate(val_loader):
        inputs, labels = data[0].to(device), data[1].to(device)

        y_pred = self.model(inputs)
        loss = self.loss_fn(y_pred, labels)
        accuracy = accuracy_score(labels.cpu().detach().numpy(), y_pred.argmax(1).cpu().detach().numpy())

        avg_losses.append(loss.item())
        avg_accuracies.append(accuracy)

    avg_loss = sum(avg_losses) / len(avg_losses)
    avg_accuracy = sum(avg_accuracies) / len(avg_accuracies)

    return avg_loss, avg_accuracy

  def test(self, best_model, test_loader):
    avg_losses = []
    avg_accuracies = []

    with torch.no_grad():
      for i, data in enumerate(test_loader):
        inputs, labels = data[0].to(device), data[1].to(device)

        y_pred = best_model(inputs)
        loss = self.loss_fn(y_pred, labels)
        accuracy = accuracy_score(labels.cpu().detach().numpy(), y_pred.argmax(1).cpu().detach().numpy())

        avg_losses.append(loss.item())
        avg_accuracies.append(accuracy)

    avg_loss = sum(avg_losses) / len(avg_losses)
    avg_accuracy = sum(avg_accuracies) / len(avg_accuracies)

    return avg_loss, avg_accuracy

  def epoch_time(self, start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

  def loss_plot(self):
    Epochs = [i for i in range(self.epochs)]
    plt.plot(Epochs, self.train_losses,'r', label="Training loss")
    plt.plot(Epochs, self.val_losses,'g', label="Validation loss")
    plt.legend()
    plt.show()

  def accuracy_plot(self):
    Epochs = [i for i in range(self.epochs)]
    multiplied_list = [element * 100 for element in self.train_accuracies]
    multiplied_list1 = [element * 100 for element in self.val_accuracies]
    plt.plot(Epochs, multiplied_list,'r', label="Training Accuracy")
    plt.plot(Epochs, multiplied_list1,'g', label="Validation Accuracy")
    plt.legend()
    plt.show()

  def save_model(self):
    PATH = '/content/drive/MyDrive/Colab Notebooks/'+self.name+'_cifar10.pth'
    torch.save(self.model.state_dict(), PATH)

# %%
alex_model = models.alexnet(pretrained=True)
alex_model.classifier[-1] = nn.Linear(4096, 10)
alex_model.features[5] = nn.MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
for parameter in alex_model.classifier[:-1].parameters():
    parameter.requires_grad = False

lr = 1e-5
epochs = 100
params = [
          {'params': alex_model.features.parameters(), 'lr': lr / 10},
          {'params': alex_model.classifier.parameters()}
         ]
optimizer = optim.Adam(params=params, lr=lr)
loss_fn = nn.CrossEntropyLoss()

alex_model.to(device)

alex = Train(name="alex", model=alex_model, optimizer=optimizer, loss_fn=loss_fn, train_loader=train_loader, val_loader=val_loader, epochs=epochs)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %%
alex.train_val()
# Out:
# Epoch: 01 | Epoch Time: 0m 11s
# 	Train Loss: 2.484 | Train Acc: 11.82%
# 	Val.  Loss: 2.366 | Val. Acc: 13.70%
# ===========================================================================
# Epoch: 02 | Epoch Time: 0m 11s
# 	Train Loss: 2.286 | Train Acc: 15.83%
# 	Val.  Loss: 2.208 | Val. Acc: 18.14%
# ===========================================================================
# Epoch: 03 | Epoch Time: 0m 11s
# 	Train Loss: 2.153 | Train Acc: 20.94%
# 	Val.  Loss: 2.098 | Val. Acc: 23.40%
# ===========================================================================
# Epoch: 04 | Epoch Time: 0m 11s
# 	Train Loss: 2.045 | Train Acc: 25.54%
# 	Val.  Loss: 2.000 | Val. Acc: 27.14%
# ===========================================================================
# Epoch: 05 | Epoch Time: 0m 11s
# 	Train Loss: 1.961 | Train Acc: 29.29%
# 	Val.  Loss: 1.919 | Val. Acc: 30.61%
# ===========================================================================
# Epoch: 06 | Epoch Time: 0m 11s
# 	Train Loss: 1.881 | Train Acc: 32.35%
# 	Val.  Loss: 1.849 | Val. Acc: 33.64%
# ===========================================================================
# Epoch: 07 | Epoch Time: 0m 11s
# 	Train Loss: 1.817 | Train Acc: 34.96%
# 	Val.  Loss: 1.790 | Val. Acc: 35.60%
# ===========================================================================
# Epoch: 08 | Epoch Time: 0m 11s
# 	Train Loss: 1.760 | Train Acc: 36.76%
# 	Val.  Loss: 1.737 | Val. Acc: 37.20%
# ===========================================================================
# Epoch: 09 | Epoch Time: 0m 11s
# 	Train Loss: 1.712 | Train Acc: 38.36%
# 	Val.  Loss: 1.693 | Val. Acc: 39.33%
# ===========================================================================
# Epoch: 10 | Epoch Time: 0m 11s
# 	Train Loss: 1.667 | Train Acc: 40.00%
# 	Val.  Loss: 1.651 | Val. Acc: 39.94%
# ===========================================================================
# Epoch: 11 | Epoch Time: 0m 11s
# 	Train Loss: 1.628 | Train Acc: 41.53%
# 	Val.  Loss: 1.614 | Val. Acc: 41.35%
# ===========================================================================
# Epoch: 12 | Epoch Time: 0m 11s
# 	Train Loss: 1.599 | Train Acc: 42.27%
# 	Val.  Loss: 1.581 | Val. Acc: 43.13%
# ===========================================================================
# Epoch: 13 | Epoch Time: 0m 11s
# 	Train Loss: 1.565 | Train Acc: 43.19%
# 	Val.  Loss: 1.557 | Val. Acc: 43.39%
# ===========================================================================
# Epoch: 14 | Epoch Time: 0m 11s
# 	Train Loss: 1.543 | Train Acc: 44.06%
# 	Val.  Loss: 1.532 | Val. Acc: 44.49%
# ===========================================================================
# Epoch: 15 | Epoch Time: 0m 11s
# 	Train Loss: 1.516 | Train Acc: 44.99%
# 	Val.  Loss: 1.505 | Val. Acc: 45.06%
# ===========================================================================
# Epoch: 16 | Epoch Time: 0m 11s
# 	Train Loss: 1.493 | Train Acc: 46.02%
# 	Val.  Loss: 1.491 | Val. Acc: 45.54%
# ===========================================================================
# Epoch: 17 | Epoch Time: 0m 11s
# 	Train Loss: 1.473 | Train Acc: 46.77%
# 	Val.  Loss: 1.477 | Val. Acc: 46.13%
# ===========================================================================
# Epoch: 18 | Epoch Time: 0m 11s
# 	Train Loss: 1.450 | Train Acc: 47.75%
# 	Val.  Loss: 1.445 | Val. Acc: 47.01%
# ===========================================================================
# Epoch: 19 | Epoch Time: 0m 11s
# 	Train Loss: 1.438 | Train Acc: 48.32%
# 	Val.  Loss: 1.441 | Val. Acc: 47.58%
# ===========================================================================
# Epoch: 20 | Epoch Time: 0m 11s
# 	Train Loss: 1.417 | Train Acc: 48.66%
# 	Val.  Loss: 1.420 | Val. Acc: 48.82%
# ===========================================================================
# Epoch: 21 | Epoch Time: 0m 11s
# 	Train Loss: 1.406 | Train Acc: 49.35%
# 	Val.  Loss: 1.403 | Val. Acc: 49.10%
# ===========================================================================
# Epoch: 22 | Epoch Time: 0m 11s
# 	Train Loss: 1.387 | Train Acc: 49.81%
# 	Val.  Loss: 1.389 | Val. Acc: 49.28%
# ===========================================================================
# Epoch: 23 | Epoch Time: 0m 11s
# 	Train Loss: 1.375 | Train Acc: 50.53%
# 	Val.  Loss: 1.380 | Val. Acc: 50.06%
# ===========================================================================
# Epoch: 24 | Epoch Time: 0m 11s
# 	Train Loss: 1.363 | Train Acc: 50.77%
# 	Val.  Loss: 1.365 | Val. Acc: 50.78%
# ===========================================================================
# Epoch: 25 | Epoch Time: 0m 11s
# 	Train Loss: 1.352 | Train Acc: 51.35%
# 	Val.  Loss: 1.357 | Val. Acc: 50.44%
# ===========================================================================
# Epoch: 26 | Epoch Time: 0m 11s
# 	Train Loss: 1.337 | Train Acc: 51.82%
# 	Val.  Loss: 1.347 | Val. Acc: 51.54%
# ===========================================================================
# Epoch: 27 | Epoch Time: 0m 11s
# 	Train Loss: 1.325 | Train Acc: 52.36%
# 	Val.  Loss: 1.347 | Val. Acc: 51.31%
# ===========================================================================
# Epoch: 28 | Epoch Time: 0m 11s
# 	Train Loss: 1.316 | Train Acc: 52.81%
# 	Val.  Loss: 1.327 | Val. Acc: 51.89%
# ===========================================================================
# Epoch: 29 | Epoch Time: 0m 11s
# 	Train Loss: 1.304 | Train Acc: 53.04%
# 	Val.  Loss: 1.316 | Val. Acc: 52.40%
# ===========================================================================
# Epoch: 30 | Epoch Time: 0m 11s
# 	Train Loss: 1.296 | Train Acc: 53.22%
# 	Val.  Loss: 1.316 | Val. Acc: 52.40%
# ===========================================================================
# Epoch: 31 | Epoch Time: 0m 11s
# 	Train Loss: 1.287 | Train Acc: 53.97%
# 	Val.  Loss: 1.307 | Val. Acc: 52.96%
# ===========================================================================
# Epoch: 32 | Epoch Time: 0m 11s
# 	Train Loss: 1.273 | Train Acc: 54.48%
# 	Val.  Loss: 1.293 | Val. Acc: 53.62%
# ===========================================================================
# Epoch: 33 | Epoch Time: 0m 11s
# 	Train Loss: 1.265 | Train Acc: 54.65%
# 	Val.  Loss: 1.283 | Val. Acc: 53.70%
# ===========================================================================
# Epoch: 34 | Epoch Time: 0m 11s
# 	Train Loss: 1.257 | Train Acc: 55.02%
# 	Val.  Loss: 1.284 | Val. Acc: 54.03%
# ===========================================================================
# Epoch: 35 | Epoch Time: 0m 11s
# 	Train Loss: 1.251 | Train Acc: 54.81%
# 	Val.  Loss: 1.270 | Val. Acc: 54.23%
# ===========================================================================
# Epoch: 36 | Epoch Time: 0m 11s
# 	Train Loss: 1.242 | Train Acc: 55.55%
# 	Val.  Loss: 1.273 | Val. Acc: 54.13%
# ===========================================================================
# Epoch: 37 | Epoch Time: 0m 11s
# 	Train Loss: 1.237 | Train Acc: 55.63%
# 	Val.  Loss: 1.265 | Val. Acc: 54.44%
# ===========================================================================
# Epoch: 38 | Epoch Time: 0m 11s
# 	Train Loss: 1.227 | Train Acc: 55.95%
# 	Val.  Loss: 1.256 | Val. Acc: 55.38%
# ===========================================================================
# Epoch: 39 | Epoch Time: 0m 11s
# 	Train Loss: 1.220 | Train Acc: 56.32%
# 	Val.  Loss: 1.252 | Val. Acc: 54.90%
# ===========================================================================
# Epoch: 40 | Epoch Time: 0m 11s
# 	Train Loss: 1.211 | Train Acc: 56.93%
# 	Val.  Loss: 1.244 | Val. Acc: 55.37%
# ===========================================================================
# Epoch: 41 | Epoch Time: 0m 11s
# 	Train Loss: 1.207 | Train Acc: 57.01%
# 	Val.  Loss: 1.240 | Val. Acc: 55.64%
# ===========================================================================
# Epoch: 42 | Epoch Time: 0m 11s
# 	Train Loss: 1.202 | Train Acc: 57.08%
# 	Val.  Loss: 1.234 | Val. Acc: 55.85%
# ===========================================================================
# Epoch: 43 | Epoch Time: 0m 11s
# 	Train Loss: 1.193 | Train Acc: 57.43%
# 	Val.  Loss: 1.231 | Val. Acc: 55.97%
# ===========================================================================
# Epoch: 44 | Epoch Time: 0m 11s
# 	Train Loss: 1.190 | Train Acc: 57.49%
# 	Val.  Loss: 1.230 | Val. Acc: 55.52%
# ===========================================================================
# Epoch: 45 | Epoch Time: 0m 12s
# 	Train Loss: 1.180 | Train Acc: 57.91%
# 	Val.  Loss: 1.216 | Val. Acc: 56.26%
# ===========================================================================
# Epoch: 46 | Epoch Time: 0m 12s
# 	Train Loss: 1.180 | Train Acc: 58.03%
# 	Val.  Loss: 1.214 | Val. Acc: 56.69%
# ===========================================================================
# Epoch: 47 | Epoch Time: 0m 11s
# 	Train Loss: 1.173 | Train Acc: 57.97%
# 	Val.  Loss: 1.213 | Val. Acc: 56.74%
# ===========================================================================
# Epoch: 48 | Epoch Time: 0m 11s
# 	Train Loss: 1.166 | Train Acc: 58.12%
# 	Val.  Loss: 1.201 | Val. Acc: 56.65%
# ===========================================================================
# Epoch: 49 | Epoch Time: 0m 11s
# 	Train Loss: 1.164 | Train Acc: 58.42%
# 	Val.  Loss: 1.199 | Val. Acc: 57.28%
# ===========================================================================
# Epoch: 50 | Epoch Time: 0m 11s
# 	Train Loss: 1.159 | Train Acc: 58.74%
# 	Val.  Loss: 1.203 | Val. Acc: 56.92%
# ===========================================================================
# Epoch: 51 | Epoch Time: 0m 11s
# 	Train Loss: 1.152 | Train Acc: 59.17%
# 	Val.  Loss: 1.187 | Val. Acc: 57.82%
# ===========================================================================
# Epoch: 52 | Epoch Time: 0m 11s
# 	Train Loss: 1.145 | Train Acc: 58.95%
# 	Val.  Loss: 1.187 | Val. Acc: 57.18%
# ===========================================================================
# Epoch: 53 | Epoch Time: 0m 11s
# 	Train Loss: 1.143 | Train Acc: 59.28%
# 	Val.  Loss: 1.188 | Val. Acc: 57.35%
# ===========================================================================
# Epoch: 54 | Epoch Time: 0m 11s
# 	Train Loss: 1.141 | Train Acc: 59.38%
# 	Val.  Loss: 1.182 | Val. Acc: 57.34%
# ===========================================================================
# Epoch: 55 | Epoch Time: 0m 11s
# 	Train Loss: 1.133 | Train Acc: 59.49%
# 	Val.  Loss: 1.174 | Val. Acc: 57.79%
# ===========================================================================
# Epoch: 56 | Epoch Time: 0m 11s
# 	Train Loss: 1.131 | Train Acc: 59.65%
# 	Val.  Loss: 1.176 | Val. Acc: 57.78%
# ===========================================================================
# Epoch: 57 | Epoch Time: 0m 11s
# 	Train Loss: 1.126 | Train Acc: 59.81%
# 	Val.  Loss: 1.175 | Val. Acc: 57.78%
# ===========================================================================
# Epoch: 58 | Epoch Time: 0m 12s
# 	Train Loss: 1.121 | Train Acc: 59.97%
# 	Val.  Loss: 1.173 | Val. Acc: 57.88%
# ===========================================================================
# Epoch: 59 | Epoch Time: 0m 11s
# 	Train Loss: 1.121 | Train Acc: 59.76%
# 	Val.  Loss: 1.171 | Val. Acc: 58.23%
# ===========================================================================
# Epoch: 60 | Epoch Time: 0m 11s
# 	Train Loss: 1.113 | Train Acc: 60.47%
# 	Val.  Loss: 1.162 | Val. Acc: 58.04%
# ===========================================================================
# Epoch: 61 | Epoch Time: 0m 11s
# 	Train Loss: 1.109 | Train Acc: 60.43%
# 	Val.  Loss: 1.169 | Val. Acc: 57.98%
# ===========================================================================
# Epoch: 62 | Epoch Time: 0m 11s
# 	Train Loss: 1.104 | Train Acc: 60.75%
# 	Val.  Loss: 1.158 | Val. Acc: 58.34%
# ===========================================================================
# Epoch: 63 | Epoch Time: 0m 11s
# 	Train Loss: 1.102 | Train Acc: 60.72%
# 	Val.  Loss: 1.163 | Val. Acc: 58.51%
# ===========================================================================
# Epoch: 64 | Epoch Time: 0m 12s
# 	Train Loss: 1.096 | Train Acc: 61.08%
# 	Val.  Loss: 1.155 | Val. Acc: 58.75%
# ===========================================================================
# Epoch: 65 | Epoch Time: 0m 12s
# 	Train Loss: 1.095 | Train Acc: 60.86%
# 	Val.  Loss: 1.152 | Val. Acc: 58.60%
# ===========================================================================
# Epoch: 66 | Epoch Time: 0m 11s
# 	Train Loss: 1.091 | Train Acc: 61.28%
# 	Val.  Loss: 1.156 | Val. Acc: 58.63%
# ===========================================================================
# Epoch: 67 | Epoch Time: 0m 12s
# 	Train Loss: 1.088 | Train Acc: 61.20%
# 	Val.  Loss: 1.149 | Val. Acc: 58.46%
# ===========================================================================
# Epoch: 68 | Epoch Time: 0m 12s
# 	Train Loss: 1.084 | Train Acc: 61.10%
# 	Val.  Loss: 1.143 | Val. Acc: 59.12%
# ===========================================================================
# Epoch: 69 | Epoch Time: 0m 12s
# 	Train Loss: 1.079 | Train Acc: 61.31%
# 	Val.  Loss: 1.144 | Val. Acc: 59.32%
# ===========================================================================
# Epoch: 70 | Epoch Time: 0m 12s
# 	Train Loss: 1.073 | Train Acc: 61.68%
# 	Val.  Loss: 1.139 | Val. Acc: 59.71%
# ===========================================================================
# Epoch: 71 | Epoch Time: 0m 12s
# 	Train Loss: 1.073 | Train Acc: 61.86%
# 	Val.  Loss: 1.136 | Val. Acc: 59.24%
# ===========================================================================
# Epoch: 72 | Epoch Time: 0m 12s
# 	Train Loss: 1.071 | Train Acc: 61.96%
# 	Val.  Loss: 1.135 | Val. Acc: 58.71%
# ===========================================================================
# Epoch: 73 | Epoch Time: 0m 12s
# 	Train Loss: 1.064 | Train Acc: 62.11%
# 	Val.  Loss: 1.130 | Val. Acc: 59.15%
# ===========================================================================
# Epoch: 74 | Epoch Time: 0m 12s
# 	Train Loss: 1.063 | Train Acc: 62.26%
# 	Val.  Loss: 1.132 | Val. Acc: 59.66%
# ===========================================================================
# Epoch: 75 | Epoch Time: 0m 12s
# 	Train Loss: 1.057 | Train Acc: 62.40%
# 	Val.  Loss: 1.134 | Val. Acc: 59.42%
# ===========================================================================
# Epoch: 76 | Epoch Time: 0m 12s
# 	Train Loss: 1.057 | Train Acc: 62.23%
# 	Val.  Loss: 1.124 | Val. Acc: 59.94%
# ===========================================================================
# Epoch: 77 | Epoch Time: 0m 12s
# 	Train Loss: 1.053 | Train Acc: 62.46%
# 	Val.  Loss: 1.121 | Val. Acc: 60.20%
# ===========================================================================
# Epoch: 78 | Epoch Time: 0m 12s
# 	Train Loss: 1.051 | Train Acc: 62.40%
# 	Val.  Loss: 1.123 | Val. Acc: 59.22%
# ===========================================================================
# Epoch: 79 | Epoch Time: 0m 12s
# 	Train Loss: 1.047 | Train Acc: 62.71%
# 	Val.  Loss: 1.121 | Val. Acc: 60.16%
# ===========================================================================
# Epoch: 80 | Epoch Time: 0m 12s
# 	Train Loss: 1.044 | Train Acc: 62.89%
# 	Val.  Loss: 1.119 | Val. Acc: 59.95%
# ===========================================================================
# Epoch: 81 | Epoch Time: 0m 12s
# 	Train Loss: 1.042 | Train Acc: 62.93%
# 	Val.  Loss: 1.123 | Val. Acc: 59.65%
# ===========================================================================
# Epoch: 82 | Epoch Time: 0m 12s
# 	Train Loss: 1.039 | Train Acc: 62.95%
# 	Val.  Loss: 1.118 | Val. Acc: 59.94%
# ===========================================================================
# Epoch: 83 | Epoch Time: 0m 12s
# 	Train Loss: 1.037 | Train Acc: 63.13%
# 	Val.  Loss: 1.117 | Val. Acc: 59.85%
# ===========================================================================
# Epoch: 84 | Epoch Time: 0m 12s
# 	Train Loss: 1.032 | Train Acc: 62.95%
# 	Val.  Loss: 1.110 | Val. Acc: 60.27%
# ===========================================================================
# Epoch: 85 | Epoch Time: 0m 12s
# 	Train Loss: 1.028 | Train Acc: 63.47%
# 	Val.  Loss: 1.113 | Val. Acc: 60.31%
# ===========================================================================
# Epoch: 86 | Epoch Time: 0m 12s
# 	Train Loss: 1.026 | Train Acc: 63.50%
# 	Val.  Loss: 1.104 | Val. Acc: 60.64%
# ===========================================================================
# Epoch: 87 | Epoch Time: 0m 12s
# 	Train Loss: 1.024 | Train Acc: 63.56%
# 	Val.  Loss: 1.106 | Val. Acc: 60.30%
# ===========================================================================
# Epoch: 88 | Epoch Time: 0m 12s
# 	Train Loss: 1.020 | Train Acc: 63.82%
# 	Val.  Loss: 1.105 | Val. Acc: 60.46%
# ===========================================================================
# Epoch: 89 | Epoch Time: 0m 12s
# 	Train Loss: 1.020 | Train Acc: 63.57%
# 	Val.  Loss: 1.106 | Val. Acc: 60.31%
# ===========================================================================
# Epoch: 90 | Epoch Time: 0m 12s
# 	Train Loss: 1.018 | Train Acc: 63.86%
# 	Val.  Loss: 1.104 | Val. Acc: 60.38%
# ===========================================================================
# Epoch: 91 | Epoch Time: 0m 12s
# 	Train Loss: 1.011 | Train Acc: 64.04%
# 	Val.  Loss: 1.101 | Val. Acc: 60.30%
# ===========================================================================
# Epoch: 92 | Epoch Time: 0m 12s
# 	Train Loss: 1.011 | Train Acc: 63.93%
# 	Val.  Loss: 1.098 | Val. Acc: 60.79%
# ===========================================================================
# Epoch: 93 | Epoch Time: 0m 12s
# 	Train Loss: 1.010 | Train Acc: 64.21%
# 	Val.  Loss: 1.089 | Val. Acc: 60.84%
# ===========================================================================
# Epoch: 94 | Epoch Time: 0m 12s
# 	Train Loss: 1.005 | Train Acc: 64.31%
# 	Val.  Loss: 1.096 | Val. Acc: 61.29%
# ===========================================================================
# Epoch: 95 | Epoch Time: 0m 11s
# 	Train Loss: 1.000 | Train Acc: 64.49%
# 	Val.  Loss: 1.089 | Val. Acc: 61.20%
# ===========================================================================
# Epoch: 96 | Epoch Time: 0m 11s
# 	Train Loss: 0.997 | Train Acc: 64.45%
# 	Val.  Loss: 1.094 | Val. Acc: 61.32%
# ===========================================================================
# Epoch: 97 | Epoch Time: 0m 12s
# 	Train Loss: 0.998 | Train Acc: 64.50%
# 	Val.  Loss: 1.098 | Val. Acc: 60.67%
# ===========================================================================
# Epoch: 98 | Epoch Time: 0m 12s
# 	Train Loss: 0.996 | Train Acc: 64.58%
# 	Val.  Loss: 1.084 | Val. Acc: 61.11%
# ===========================================================================
# Epoch: 99 | Epoch Time: 0m 12s
# 	Train Loss: 0.995 | Train Acc: 64.56%
# 	Val.  Loss: 1.082 | Val. Acc: 61.60%
# ===========================================================================
# Epoch: 100 | Epoch Time: 0m 12s
# 	Train Loss: 0.990 | Train Acc: 64.80%
# 	Val.  Loss: 1.086 | Val. Acc: 61.25%
# ===========================================================================

# %%
alex.loss_plot()

# %%
alex.accuracy_plot()

# %%
best_model = models.alexnet(pretrained=True)
best_model.classifier[-1] = nn.Linear(4096, 10)
best_model.features[5] = nn.MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
for parameter in best_model.classifier[:-1].parameters():
    parameter.requires_grad = False

best_model.to(device)
best_model.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/Validation_state/alex.pth'))

test_loss, test_accuracy = alex.test(best_model, test_loader)
print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_accuracy*100:.2f}%')
# Out:
# Test Loss: 1.105 | Test Acc: 61.05%

# %%
def get_predictions(model, iterator):

    model.eval()

    images = []
    labels = []
    probs = []

    with torch.no_grad():

        for (x, y) in iterator:

            x = x.to(device)

            y_pred = model(x)

            y_prob = F.softmax(y_pred, dim = -1)
            top_pred = y_prob.argmax(1, keepdim = True)

            images.append(x.cpu())
            labels.append(y.cpu())
            probs.append(y_prob.cpu())

    images = torch.cat(images, dim = 0)
    labels = torch.cat(labels, dim = 0)
    probs = torch.cat(probs, dim = 0)

    return images, labels, probs

def plot_confusion_matrix(labels, pred_labels, classes):
    
    fig = plt.figure(figsize = (10, 10));
    ax = fig.add_subplot(1, 1, 1);
    cm = confusion_matrix(labels, pred_labels);
    cm = ConfusionMatrixDisplay(cm, display_labels = classes);
    cm.plot(values_format = 'd', cmap = 'Blues', ax = ax)
    plt.xticks(rotation = 20)

# %%
images, labels, probs = get_predictions(best_model, test_loader)
pred_labels = torch.argmax(probs, 1)
classes = test_data.classes
plot_confusion_matrix(labels, pred_labels, classes)

# %% [markdown]
# precision:- OF all the images that have been classified for that class, how many did we correctly classify <br>
# recall : - of all the images that have been truly classified for that class, how many did we label for that class

# %%
print(f'{classification_report(labels, pred_labels)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.65      0.67      1000
#            1       0.65      0.69      0.67      1000
#            2       0.57      0.51      0.54      1000
#            3       0.47      0.41      0.44      1000
#            4       0.59      0.55      0.57      1000
#            5       0.55      0.54      0.54      1000
#            6       0.67      0.76      0.71      1000
#            7       0.64      0.67      0.66      1000
#            8       0.73      0.76      0.75      1000
#            9       0.64      0.70      0.67      1000
#
#     accuracy                           0.62     10000
#    macro avg       0.62      0.62      0.62     10000
# weighted avg       0.62      0.62      0.62     10000
